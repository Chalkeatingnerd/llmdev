# %% [markdown]
# # lession 0
#
# - vs code basic usage
#
# |title1|title2|
# |------|------|
# |data1|data1|
# |data2|data2|
# |data3|data3|

# %%
print("Hello World!")
print("changes")
# Out:
# Hello World!
# changes
