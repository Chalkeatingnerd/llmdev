# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")
os.environ['OPENAI_API_KEY']  = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# Indexの構築
documents = SimpleDirectoryReader('./data/text').load_data()
index = VectorStoreIndex.from_documents(documents)

# Chat Engineの作成
llm = OpenAI(model=MODEL_NAME)
chat_engine = index.as_chat_engine(llm=llm, chat_mode="openai")

print("--- 質問を入力してください (入力なかったら終了) ---")

# チャットの開始
while(True):
    message = input("メッセージを入力:")
    if message.strip() == "":
        break
    
    print(f"\n質問: {message}")

    response = chat_engine.chat(message)

    print(f"回答: {response.response}\n")

print("\n---ご利用ありがとうございました！---")
# Out:
# --- 質問を入力してください (入力なかったら終了) ---
#
# 質問: こんにちは
# 回答: こんにちは！今日はどのようにお手伝いできますか？
#
#
# 質問: 退職流れの説明お願い
# 回答: 退職の流れは以下の通りです。
#
# 1. **退職の申し出と届け出**: 自己都合退職を希望する場合、退職希望日の1ヶ月前までに直属の上司に申し出る必要があります。また、退職届を提出し、その後、退職日や引き継ぎ内容について上司と人事部と協議します。
#
# 2. **引き継ぎ**: 退職が決まった後は、担当業務の進捗や内容、必要な手順を文書にまとめ、後任者へ引き継ぎます。
#
# 3. **社内備品の返却**: 会社の備品（パソコン、スマートフォン、IDカード、制服など）を退職日までに返却します。
#
# 4. **最終面談**: 人事部による退職面談が実施され、退職理由や今後のキャリア計画について意見を伺います。
#
# 5. **退職日の決定**: 退職日は業務の都合や引き継ぎ内容を考慮し、上司および人事部と話し合いの上で最終決定されます。
#
# 何か他に知りたいことがあれば教えてください！
#
#
# ---ご利用ありがとうございました！---
