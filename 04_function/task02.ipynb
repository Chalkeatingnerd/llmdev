# %%
import urllib.request
from datetime import datetime

def save_url_content(url):
    """
    指定されたURLのコンテンツを取得し、先頭500文字を日時をファイル名にして保存する関数
    """
    now = datetime.now()
    file_name = now.strftime("%Y%m%d_%H%M%S.txt")
    
    try:
        with urllib.request.urlopen(url) as response:
            content = response.read().decode("utf-8")
            
            snippet = content[:500]
            
            with open(file_name, "w", encoding="utf-8") as file:
                file.write(snippet)
                
        return file_name

    except Exception as e:
        return f"エラーが発生しました: {e}"

url = input("URLを入力してください: ")
file_name = save_url_content(url)
print(f"Content saved in: {file_name}")
# Out:
# Content saved in: 20260227_142840.txt
