# %%
# grades = [85, 90, 78, 92, 88]
grades = [70, 75, 80, 85, 90]

average = sum(grades) / len(grades)

max_grade = max(grades)
min_grade = min(grades)

above_average_count = len([g for g in grades if g >= average])

print(f"成績リスト: {grades}")
print(f"平均点: {average:.1f}")
print(f"最高点: {max_grade}")
print(f"最低点: {min_grade}")
print(f"平均以上の学生数: {above_average_count}")
# Out:
# 成績リスト: [70, 75, 80, 85, 90]
# 平均点: 80.0
# 最高点: 90
# 最低点: 70
# 平均以上の学生数: 3
